# %% [markdown]
# <a href="https://colab.research.google.com/github/egg7bnn/2024-2/blob/main/%EB%8D%B0%EC%9D%B4%ED%84%B0%EB%B6%84%EC%84%9D%EC%9E%85%EB%AC%B8/chapter1/section1/ColabTest.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys

# %%
sys.version
# Out:
# '3.10.12 (main, Sep 11 2024, 15:47:36) [GCC 11.4.0]'

# %%
import site

# %%
site.getsitepackages()
# Out:
# ['/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/lib/python3.10/dist-packages']

# %%
# %config InlineBackend.figure_format = 'retina'

# %%
# !pip install koreanize-matplotlib
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 40.8 MB/s eta 0:00:00
# ...

# %%
import koreanize_matplotlib
import matplotlib.pyplot as plt

# %%
import matplotlib.pyplot as plt

plt.title ('데이터 시각화의 한글 준비와 기본 직선 그래프')
plt.plot([10, 5, 20, 30])
plt.show()

# %%
import pandas as pd
pop = pd.read_csv("202311popmonth.csv", encoding = 'cp949', index_col=0, thousands=',')
pop
# Out:
#                        2024년10월_총인구수  2024년10월_세대수  2024년10월_세대당 인구  \
# 행정구역
# 전국  (1000000000)            51238450      24105045             2.13
# 서울특별시  (1100000000)          9343304       4484218             2.08
# 부산광역시  (2600000000)          3271062       1570658             2.08
# 대구광역시  (2700000000)          2364892       1103045             2.14
# 인천광역시  (2800000000)          3017928       1371450             2.20
# 광주광역시  (2900000000)          1410548        657981             2.14
# 대전광역시  (3000000000)          1440094        687677             2.09
# 울산광역시  (3100000000)          1098540        494846             2.22
# 세종특별자치시  (3600000000)         389978        163177             2.39
# 경기도  (4100000000)           13686731       6049474             2.26
# 강원특별자치도  (5100000000)        1519545        764838             1.99
# 충청북도  (4300000000)           1590704        786482             2.02
# 충청남도  (4400000000)           2136010       1050910             2.03
# ...

# %%
pop.columns = ['총인구수', '세대수', '세대당인구', '남자인구수', '여자인구수', '남여비율']

# %%
pop.head()
# Out:
#                          총인구수       세대수  세대당인구     남자인구수     여자인구수  남여비율
# 행정구역
# 전국  (1000000000)     51238450  24105045   2.13  25511290  25727160  0.99
# 서울특별시  (1100000000)   9343304   4484218   2.08   4511734   4831570  0.93
# 부산광역시  (2600000000)   3271062   1570658   2.08   1592440   1678622  0.95
# 대구광역시  (2700000000)   2364892   1103045   2.14   1160429   1204463  0.96
# 인천광역시  (2800000000)   3017928   1371450   2.20   1507849   1510079  1.00

# %%
pop.index = [pop.index[i].split()[0] for i in range(len(pop.index))]
pop
# Out:
#              총인구수       세대수  세대당인구     남자인구수     여자인구수  남여비율
# 전국       51238450  24105045   2.13  25511290  25727160  0.99
# 서울특별시     9343304   4484218   2.08   4511734   4831570  0.93
# 부산광역시     3271062   1570658   2.08   1592440   1678622  0.95
# 대구광역시     2364892   1103045   2.14   1160429   1204463  0.96
# 인천광역시     3017928   1371450   2.20   1507849   1510079  1.00
# 광주광역시     1410548    657981   2.14    696227    714321  0.97
# 대전광역시     1440094    687677   2.09    717893    722201  0.99
# 울산광역시     1098540    494846   2.22    565011    533529  1.06
# 세종특별자치시    389978    163177   2.39    194110    195868  0.99
# 경기도      13686731   6049474   2.26   6879539   6807192  1.01
# 강원특별자치도   1519545    764838   1.99    764109    755436  1.01
# 충청북도      1590704    786482   2.02    809530    781174  1.04
# 충청남도      2136010   1050910   2.03   1095772   1040238  1.05
# 전북특별자치도   1740753    864295   2.01    866902    873851  0.99
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.scatterplot(pop['총인구수'])
plt.xticks(rotation=90)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

pop1 = pop.sort_values('총인구수')
sns.barplot(x=pop1.index, y='총인구수', data=pop1)
plt.xticks(rotation=90)
plt.show()
